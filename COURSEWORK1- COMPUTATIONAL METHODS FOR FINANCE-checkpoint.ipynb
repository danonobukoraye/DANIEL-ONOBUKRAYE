# %% [markdown]
# ## CODE FOR NEAR_USD CRYPTO

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
initial_data = yf.download("NEAR-USD", start="2020-11-28", end="2022-11-28")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
initial_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2020-11-28  0.996618  1.037513  0.961482  1.021969   1.021969  21095716
# 2020-11-29  1.021947  1.043428  0.992504  1.014594   1.014594  19269022
# 2020-11-30  1.014529  1.095488  1.006276  1.076078   1.076078  24145337
# 2020-12-01  1.076825  1.130298  0.996890  1.060105   1.060105  65515679
# 2020-12-02  1.059534  1.196684  1.031078  1.175250   1.175250  40593260

# %%
initial_data['Adj Close'].head()
# Out:
# Date
# 2020-11-28    1.021969
# 2020-11-29    1.014594
# 2020-11-30    1.076078
# 2020-12-01    1.060105
# 2020-12-02    1.175250
# Name: Adj Close, dtype: float64

# %%
data =  initial_data['Adj Close']
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 730 entries, 2020-11-28 to 2022-11-27
# Series name: Adj Close
# Non-Null Count  Dtype
# --------------  -----
# 730 non-null    float64
# dtypes: float64(1)
# memory usage: 11.4 KB

# %%
data.head()
# Out:
# Date
# 2020-11-28    1.021969
# 2020-11-29    1.014594
# 2020-11-30    1.076078
# 2020-12-01    1.060105
# 2020-12-02    1.175250
# Name: Adj Close, dtype: float64

# %%
data.tail()
# Out:
# Date
# 2022-11-23    1.687387
# 2022-11-24    1.643978
# 2022-11-25    1.645803
# 2022-11-26    1.609567
# 2022-11-27    1.613732
# Name: Adj Close, dtype: float64

# %%
data.plot(figsize=(8, 4), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %%
data.describe().round(2)
# Out:
# count    730.00
# mean       6.26
# std        4.22
# min        0.87
# 25%        3.14
# 50%        4.90
# 75%        9.11
# max       20.20
# Name: Adj Close, dtype: float64

# %%
initial_dataa = yf.download("NEAR-USD", start="2021-11-28", end="2022-11-28")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
initial_dataa['Adj Close'].head()
# Out:
# Date
# 2021-11-28    8.390302
# 2021-11-29    8.437941
# 2021-11-30    8.762621
# 2021-12-01    8.511616
# 2021-12-02    8.229185
# Name: Adj Close, dtype: float64

# %%
data =  initial_dataa['Adj Close']
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 365 entries, 2021-11-28 to 2022-11-27
# Series name: Adj Close
# Non-Null Count  Dtype
# --------------  -----
# 365 non-null    float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %%
data.head()
# Out:
# Date
# 2021-11-28    8.390302
# 2021-11-29    8.437941
# 2021-11-30    8.762621
# 2021-12-01    8.511616
# 2021-12-02    8.229185
# Name: Adj Close, dtype: float64

# %%
data.tail()
# Out:
# Date
# 2022-11-23    1.687387
# 2022-11-24    1.643978
# 2022-11-25    1.645803
# 2022-11-26    1.609567
# 2022-11-27    1.613732
# Name: Adj Close, dtype: float64

# %%
data.plot(figsize=(8, 4), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %%
data.describe().round(2)
# Out:
# count    365.00
# mean       7.77
# std        4.76
# min        1.56
# 25%        3.68
# 50%        5.75
# 75%       11.20
# max       20.20
# Name: Adj Close, dtype: float64

# %%
df=data[-365:-1]
df.head()
# Out:
# Date
# 2021-11-28    8.390302
# 2021-11-29    8.437941
# 2021-11-30    8.762621
# 2021-12-01    8.511616
# 2021-12-02    8.229185
# Name: Adj Close, dtype: float64

# %%
log_return = np.log(df / df.shift(1))
log_return
# Out:
# Date
# 2021-11-28         NaN
# 2021-11-29    0.005662
# 2021-11-30    0.037757
# 2021-12-01   -0.029063
# 2021-12-02   -0.033745
#                 ...
# 2022-11-22    0.040487
# 2022-11-23    0.038399
# 2022-11-24   -0.026062
# 2022-11-25    0.001109
# 2022-11-26   -0.022263
# Name: Adj Close, Length: 364, dtype: float64

# %%
initial_dataa = yf.download("NEAR-USD", start="2021-11-28", end="2022-11-28")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
log_retun = np.log(initial_dataa['Adj Close'].shift(1))

# %%
fig = plt.figure()
plt.plot(log_return)
#plt.plot(log_return, np.maximum(S-20.20))
plt.xlabel('Date')
plt.ylabel('log return')
plt.title('Log Return')
plt.show()

# %%
vol = np.sqrt(365) * log_return.std()
print('The annualised volatility is', round(vol*100,2), '%')
# Out:
# The annualised volatility is 135.69 %

# %%
df[-1] #spot price
# Out:
# 1.6095670461654663

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as si
import yfinance as yf

# %%
def euro_option_bs(S, K, T, r, vol, payoff):
    
    #S: spot price #1.60
    #K: strike price #1.60
    #T: time to maturity #1
    #r: risk free rate #0.036
    #vol: volatility of underlying asset # 1.35
    #payoff: call or put
    
    d1 = (np.log(S / K) + (r + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        option_value = S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    
    return option_value

# %%
euro_option_bs(1.60, 1.60, 1, 0.036, 1.35, 'call')
# Out:
# 0.8148930953365034

# %%
S = np.linspace(1.2,6.0,11)
cp = np.zeros((len(S),1))
for i in range(len(S)):
    cp[i] = euro_option_bs(S[i], 1.60, 1, 0.036, 1.35, 'call')

# %%
fig = plt.figure()
plt.plot(S, cp, '-')
plt.plot(S, np.maximum(S-1.60,0), '--')
plt.xlabel('Asset Price')
plt.ylabel('Price')
plt.title('European Call')
plt.legend(['Option Price','Payoff at T'])

# %% [markdown]
# ## METHOLOGOGIES

# %% [markdown]
# #1 )BLACK-SCHOLES MODEL : This model estimates the theoretical value of derivatives based on other investment instruments, taking into account the impact of time and other risk factors.

# %%
def euro_option_bs(S, K, T, r, vol, payoff):
    
    
    d1 = (np.log(S / K) + (r + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        option_value = S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        option_value = - S * si.norm.cdf(-d1, 0.0, 1.0) + K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return option_value

# %%
s = 1.60        #Spot Price
K = 1.60        #Strike Price
T = 1           #Time
r = 0.036       #Risk Free Rate
q = 0           #Dividend 
vol = 1.35      #Volatility

# %%
euro_option_bs(s, K, T, r, vol, 'call')
# Out:
# 0.8148930953365034

# %% [markdown]
# #2) MONTE CARLO SIMULATION: This model is used to predict the probability of a variety of outcomes when the potential for random variables is given. It assist to explain the impact of risk and uncertainty in prediction and forecasting.

# %%
def mcs_simulation_np(p):
    M = p
    I = p
    dt = T / M 
    S = np.zeros((M + 1, I))
    S[0] = S0 
    rn = np.random.standard_normal(S.shape) 
    for t in range(1, M + 1): 
        S[t] = S[t-1] * np.exp((r - sigma ** 2 / 2) * dt + sigma * np.sqrt(dt) * rn[t]) 
    return S

# %%
T = 1
r = 0.036
sigma = 1.35
S0 = 1.60
K = 1.60

# %%
S = mcs_simulation_np(1000)

# %%
S = np.transpose(S)
S
# Out:
# array([[1.6       , 1.54470249, 1.5582612 , ..., 0.11884393, 0.11541308,
#         0.11435352],
#        [1.6       , 1.66300032, 1.6744914 , ..., 0.40705152, 0.39244412,
#         0.39945552],
#        [1.6       , 1.58218775, 1.61557271, ..., 3.5543493 , 3.51945126,
#         3.4849466 ],
#        ...,
#        [1.6       , 1.51074965, 1.58804946, ..., 1.38369758, 1.38224091,
#         1.41213281],
#        [1.6       , 1.60961598, 1.63686391, ..., 0.81631186, 0.79294206,
#         0.77791577],
#        [1.6       , 1.61485098, 1.65215089, ..., 3.18474877, 3.13851556,
#         3.05362921]])

# %%
c = np.mean(np.maximum(S[:,-1] - K,0))
print('European call', str(c))
# Out:
# European call 0.7152470808511737

# %%
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(x=S[:,-1], bins='auto', color='#0504aa',alpha=0.9, rwidth=0.8)

plt.grid(axis='y', alpha=0.9)
plt.xlabel('S_T')
plt.ylabel('Frequency')
plt.title('Frequency distribution of the simulated end-of-preiod values')
# Out:
# Text(0.5, 1.0, 'Frequency distribution of the simulated end-of-preiod values')

# %% [markdown]
# # GREEKS FOR RISK MANAGEMENT

# %% [markdown]
# 1) DELTA : This measures the rate of the change of the theoritical option with respect to changes in the underlying asset price.

# %%
def delta(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        delta = np.exp(- q * T) * si.norm.cdf(d1, 0.0, 1.0)
    elif payoff == "put":
        delta =  - np.exp(- q * T) * si.norm.cdf(- d1, 0.0, 1.0)
    
    return delta

# %%
S = np.linspace(0.9, 2, 35)
T = np.linspace(0.9, 1.5, 35)
Delta = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Delta[i,j] = delta(S[j], 1.6, T[i], 0.036, 0, 1.35, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Delta, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('price of cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Delta')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\DANIEL O'RAYE\AppData\Local\Temp\ipykernel_18508\3601117308.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
delta(1.60, 1.60, 1, 0.036, 0, 1.35, 'call')
# Out:
# 0.7585564672962907

# %% [markdown]
# From the above, the Delta value is $ 0.75 dollar. This implies that if the asset price increases by 1 the value of the option will increase $ 0.75 dollar

# %% [markdown]
# 2) SPEED : This measures the rate of change in gamma with respect to change in the underlying asset price. It is a third order drivative.

# %%
def speed(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    speed = - np.exp(- q * T) * si.norm.pdf(d1, 0.0, 1.0) / ((vol **2) * (S**2) * np.sqrt(T)) * (d1 + vol * np.sqrt(T))
    
    return speed

# %%
S = np.linspace(0.9, 2, 35)
T = np.linspace(0.9, 1.5, 35)
Speed = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Speed[i,j] = speed(S[j], 2, T[i], 0.036, 0, 1.35, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Speed, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Price of Cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Speed')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\DANIEL O'RAYE\AppData\Local\Temp\ipykernel_18508\3090571425.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
speed(1.60, 1.60, 1, 0.036, 0, 1.35, 'call')
# Out:
# -0.1371513029880321

# %% [markdown]
# 'From the above, if asset increase from 100 to 101, gamma will decrease by -0.13%.

# %% [markdown]
# 3) VEGA: This measures the sensitivity of the option price to volatility.

# %%
def vega(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    vega = S * np.sqrt(T) * np.exp(-q * T) * si.norm.pdf(d1, 0.0, 1.0)
    
    return vega

# %%
S = np.linspace(1, 2, 35)
T = np.linspace(0.9, 1.5, 35)
Vega = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Vega[i,j] = vega(S[j], 1.6, T[i], 0.036, 0, 1.35, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Vega, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Asset Price')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Vega')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\DANIEL O'RAYE\AppData\Local\Temp\ipykernel_18508\1413777336.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
vega(1.60, 1.60, 1, 0.036, 0, 1.35, 'call')
# Out:
# 0.4990230661674446

# %% [markdown]
# 'As seen from the above result, if the volatility increases 1%, then the value of the option will increase $0.499

# %% [markdown]
# 4) RHO: This measures sensitivity f insterest rate. It is the leaset used of the greeks.

# %%
def rho(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        rho =  K * T * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        rho = - K * T * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return rho

# %%
S = np.linspace(0.9, 2, 35)
T = np.linspace(0.9, 1.5, 35)
Rho = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Rho[i,j] = rho(S[j], 1.6, T[i], 0.036, 0, 1.35, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Rho, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Asset Price')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Rho')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\DANIEL O'RAYE\AppData\Local\Temp\ipykernel_18508\448265538.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
S = 1.6    
k = 1.6
T = 1
r = 0.036
vol = 1.35

# %%
rho(1.60, 1.60, 1, 0.036, 0, 1.35, 'call')
# Out:
# 0.39879725233756186

# %% [markdown]
# The above result shows that if interest rate increase by 1%, the option value will by $0.39

# %% [markdown]
# 5) GAMMA: This measures the rate of change in Delta with respect to changes in the underlying price.

# %%
def gamma(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    gamma = np.exp(- r * T) * si.norm.pdf(d1, 0.0, 1.0) / (vol * S * np.sqrt(T))
    
    return gamma

# %%
S = np.linspace(0.9, 2, 35)
T = np.linspace(0.9, 1.2, 35)
Gamma = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Gamma[i,j] = gamma(S[j], 1.6, T[i], 0.036, 0, 1.35, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Gamma, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Asset Price')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Gamma')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\DANIEL O'RAYE\AppData\Local\Temp\ipykernel_18508\3478852474.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
gamma(1.60, 1.60, 1, 0.036, 0, 1.35, 'call')
# Out:
# 0.1392875454289964

# %% [markdown]
# From the above result, if gamma increases by $1, Delta will increase by 0.139.
